# %% [markdown]
# ## Table Metadata extraction from PDF Files using Camelot

# %% [markdown]
# Requirements:
# - camelot
# - cv

# %% [markdown]
# ### Install requirements
#
# - !pip install "camelot-py[base]"
# - Refer here for more details : https://camelot-py.readthedocs.io/en/master/

# %%
import camelot

# %% [markdown]
# #### Experimentation with different types of tables
#
# We experiment with different types of tables and see how good they camelot is in extracting table information

# %% [markdown]
# ### Background lines : Type 1
#
# ![1.png](attachment:1.png)

# %%
# extract all the tables in the PDF file

tables = camelot.read_pdf("C:/Users/LENOVO/Desktop/Projects/Data Extraction/data/Table data/background_lines_1.pdf", pages = 'all', flavor = "lattice")   #address of file location

# %%
print(f'Number of Tables : {tables.n}')
# Out:
# Number of Tables : 1

# %%
df = tables[0].df

# %%
df
# Out:
#                                                    0 1 2
# 0  The Red Ribbon Express (RRE) is the world’s la...
# 1
# 2

# %% [markdown]
# ### Background lines : Type 2
#
# ![2.png](attachment:2.png)

# %%
# extract all the tables in the PDF file

tables = camelot.read_pdf("C:/Users/LENOVO/Desktop/Projects/Data Extraction/data/Table data/background_lines_2.pdf", pages = 'all', flavor = "stream")   #address of file location

# %%
print(f'Number of Tables : {tables.n}')
# Out:
# Number of Tables : 1

# %%
df = tables[0].df

# %%
df
# Out:
#      0                         1       2            3  4      5      6   \
# 0                                          THE  MANURE
# 1   (1)                       (2)     (3)          (4)       (5)    (6)
# 2            MARGINAL (BELOW 1.0)
# 3                               I   39053               0  12142   3322
# 4     1
# 5                              UI    7429               0   2088   1560
# 6                               T   46484               0  14230   4882
# 7              SMALL (1.0 - 1.99)
# 8                               I   20341               0  16685   1631
# 9     2
# 10                             UI    6854               0   4594   1885
# 11                              T   27197               0  21279   3516
# 12       SEMI-MEDIUM (2.0 - 3.99)
# 13                              I   20800               0  16991   7643
# 14    3
# 15                             UI    5856               0   1017   4819
# ...

# %% [markdown]
# ### Column header rotated
#
# ![3.png](attachment:3.png)

# %%
# extract all the tables in the PDF file

tables = camelot.read_pdf("C:/Users/LENOVO/Desktop/Projects/Data Extraction/data/Table data/column_header_rotated.pdf", pages = 'all', flavor = "lattice")   #address of file location

# %%
print(f'Number of Tables : {tables.n}')
# Out:
# Number of Tables : 1

# %%
df = tables[0].df

# %%
df
# Out:
#           0             1                                               2   \
# 0   Sl.\nNo.      District  Projected Population \nfor 2012-13\n(In lakhs)
# 1
# 2          1      Balasore                                           23.65
# 3          2       Bhadrak                                           15.34
# 4          3      Balangir                                           17.01
# 5          4    Subarnapur                                            6.70
# 6          5       Cuttack                                           26.63
# 7          6  Jagatsingpur                                           11.49
# 8          7        Jajpur                                           18.59
# 9          8    Kendrapara                                           14.62
# 10         9     Dhenkanal                                           12.13
# 11        10         Angul                                           12.93
# ...

# %% [markdown]
# ### Column Spanned : Type 1
#
# ![4.png](attachment:4.png)

# %%
# extract all the tables in the PDF file

tables = camelot.read_pdf("C:/Users/LENOVO/Desktop/Projects/Data Extraction/data/Table data/column_span_1.pdf", pages = 'all', flavor = "lattice")   #address of file location

# %%
print(f'Number of Tables : {tables.n}')
# Out:
# Number of Tables : 1

# %%
df = tables[0].df

# %%
df
# Out:
#             0     1                       2                  3     4  \
# 0   Sl. \nNo.  Year  Population \n(in Lakh)  Accidental Deaths
# 1                                                    Incidence  Rate
# 2         (1)   (2)                     (3)                (4)   (5)
# 3          1.  1967                    4999             126762  25.4
# 4          2.  1968                    5111             126232  24.7
# 5          3.  1969                    5225             130755  25.0
# 6          4.  1970                    5343             139752  26.2
# 7          5.  1971                    5512             105601  19.2
# 8          6.  1972                    5635             106184  18.8
# 9          7.  1973                    5759             130654  22.7
# 10         8.  1974                    5883             110624  18.8
# 11         9.  1975                    6008             113016  18.8
# 12        10.  1976                    6136             111611  18.2
# ...

# %% [markdown]
# ### Column Spanned : Type 2
#
# ![5.png](attachment:5.png)

# %%
# extract all the tables in the PDF file

tables = camelot.read_pdf("C:/Users/LENOVO/Desktop/Projects/Data Extraction/data/Table data/column_span_2.pdf", pages = 'all', flavor = "lattice")   #address of file location

# %%
print(f'Number of Tables : {tables.n}')
# Out:
# Number of Tables : 1

# %%
df = tables[0].df

# %%
df
# Out:
#                                       0            1  \
# 0                        Investigations  No. of\nHHs
# 1                         Anthropometry         2400
# 2                  Clinical Examination
# 3                  History of morbidity
# 4                           Diet survey         1200
# 5                      Blood Pressure #         2400
# 6
# 7                 Fasting blood glucose         2400
# 8
# 9   Knowledge &\nPractices on HTN &\nDM         2400
# 10                                              2400
#
#                                                     2    3    4    5     6
# 0   Age/Sex/\nPreva-\nC.I*\nRelative\nSample size\...
# 1                       All the available individuals
# 2
# 3
# 4       All the individuals partaking meals in the HH
# 5                                       Men (≥ 18yrs)  10%  95%  20%  1728
# 6                                    Women (≥ 18 yrs)                 1728
# ...

# %% [markdown]
# ### Electoral Roll
#
# ![6.png](attachment:6.png)

# %%
# extract all the tables in the PDF file

tables = camelot.read_pdf("C:/Users/LENOVO/Desktop/Projects/Data Extraction/data/Table data/electoral_roll.pdf", pages = 'all', flavor = "lattice")   #address of file location

# %%
print(f'Number of Tables : {tables.n}')
# Out:
# Number of Tables : 10

# %%
df = tables[0].df

# %%
df
# Out:
#                                                    0  \
# 0                                     1 \nNEL0000001
# 1  Name :\nJohn Doe\nFather's \n:\nName\n0\nHouse...
#
#                                                    1  \
# 0                                     2 \nNEL0000002
# 1  Name :\nJohn Doe\nFather's \n:\nName\n15\nHous...
#
#                                                    2
# 0                                     3 \nNEL0000003
# 1  Name :\nJohn Doe\nFather's \n:\nName\n15\nHous...

# %% [markdown]
# ### Rotated Table
#
# ![7.png](attachment:7.png)

# %%
# extract all the tables in the PDF file

tables = camelot.read_pdf("C:/Users/LENOVO/Desktop/Projects/Data Extraction/data/Table data/rotated.pdf", pages = 'all', flavor = "lattice")   #address of file location

# %%
print(f'Number of Tables : {tables.n}')
# Out:
# Number of Tables : 1

# %%
df = tables[0].df

# %%
df
# Out:
#                  0                                               1        2  \
# 0            State  Nutritional Assessment  \n(No. of individuals)
# 1                                                          1975-79  1988-90
# 2           Kerala                                            5738     6633
# 3       Tamil Nadu                                            7387    10217
# 4        Karnataka                                            6453     8138
# 5   Andhra Pradesh                                            5844     9920
# 6      Maharashtra                                            5161     7796
# 7          Gujarat                                            4403     5374
# 8   Madhya Pradesh                                               *        *
# 9           Orissa                                            3756     5540
# 10     West Bengal                                               *        *
# ...

# %% [markdown]
# ### Rows Spanned
#
# ![8.png](attachment:8.png)

# %%
# extract all the tables in the PDF file

tables = camelot.read_pdf("C:/Users/LENOVO/Desktop/Projects/Data Extraction/data/Table data/row_span.pdf", pages = 'all', flavor = "lattice")   #address of file location

# %%
print(f'Number of Tables : {tables.n}')
# Out:
# Number of Tables : 1

# %%
df = tables[0].df

# %%
df
# Out:
#                                                     0                      1  \
# 0                                           Plan Type                 County
# 1                                                 GMC             Sacramento
# 2
# 3
# 4
# 5                                                                  San Diego
# 6
# 7
# 8
# 9
# 10                                                      Total GMC Enrollment
# 11                                               COHS                  Marin
# 12                                                                 Mendocino
# 13                                                                      Napa
# 14                                                                    Solano
# 15                                                                    Sonoma
# 16                                                                      Yolo
# 17                                                                 Del Norte
# ...

# %% [markdown]
# ### Tables spanning multiple pages
#
# ![9.png](attachment:9.png)

# %%
# extract all the tables in the PDF file

tables = camelot.read_pdf("C:/Users/LENOVO/Desktop/Projects/Data Extraction/data/Table data/table_overlap.pdf", pages = 'all', flavor = "lattice")   #address of file location

# %%
print(f'Number of Tables : {tables.n}')
# Out:
# Number of Tables : 2

# %%
df_firstpart = tables[0].df

# %%
df_firstpart
# Out:
#                     0       1       2       3        4        5       6
# 0               State  Mar-19  Mar-20  Growth  2018-19  2019-20  Growth
# 1   Jammu and Kashmir     388     276    -29%    3,792    4,010      6%
# 2    Himachal Pradesh     660     596    -10%    7,593    7,960      5%
# 3              Punjab   1,166   1,181      1%   13,979   15,235      9%
# 4          Chandigarh     162     153     -5%    1,779    1,988     12%
# 5         Uttarakhand   1,451   1,195    -18%   15,150   14,722     -3%
# 6             Haryana   4,561   4,874      7%   55,233   59,560      8%
# 7               Delhi   3,722   3,273    -12%   39,845   44,161     11%
# 8           Rajasthan   3,132   2,820    -10%   30,722   32,821      7%
# 9       Uttar Pradesh   5,548   5,294     -5%   61,337   65,281      6%
# 10              Bihar   1,177   1,056    -10%   10,755   12,640     18%
# 11             Sikkim     160     189     19%    1,917    2,248     17%
# ...

# %%
df_secondpart = tables[1].df

# %%
df_secondpart
# Out:
#                            0       1       2     3         4         5     6
# 0               Chhattisgarh   2,143   2,093   -2%    22,932    24,160    5%
# 1             Madhya Pradesh   2,624   2,407   -8%    25,683    28,354   10%
# 2                    Gujarat   6,521   6,820    5%    73,440    78,923    7%
# 3              Daman and Diu     103      95   -8%     1,105     1,155    5%
# 4     Dadra and Nagar Haveli     174     169   -3%     1,718     1,810    5%
# 5                Maharashtra  15,596  15,002   -4%  1,70,289  1,85,917    9%
# 6                  Karnataka   6,983   7,144    2%    78,763    83,408    6%
# 7                        Goa     389     316  -19%     4,103     4,280    4%
# 8                Lakshadweep       1       1   54%        20        20    2%
# 9                     Kerala   1,635   1,475  -10%    16,343    19,234   18%
# 10                Tamil Nadu   6,941   6,178  -11%    70,562    74,430    5%
# ...

# %%
### Getting full table back

df = df_firstpart.append(df_secondpart)
df
# Out:
#                            0       1       2       3         4         5  \
# 0                      State  Mar-19  Mar-20  Growth   2018-19   2019-20
# 1          Jammu and Kashmir     388     276    -29%     3,792     4,010
# 2           Himachal Pradesh     660     596    -10%     7,593     7,960
# 3                     Punjab   1,166   1,181      1%    13,979    15,235
# 4                 Chandigarh     162     153     -5%     1,779     1,988
# 5                Uttarakhand   1,451   1,195    -18%    15,150    14,722
# 6                    Haryana   4,561   4,874      7%    55,233    59,560
# 7                      Delhi   3,722   3,273    -12%    39,845    44,161
# 8                  Rajasthan   3,132   2,820    -10%    30,722    32,821
# 9              Uttar Pradesh   5,548   5,294     -5%    61,337    65,281
# 10                     Bihar   1,177   1,056    -10%    10,755    12,640
# 11                    Sikkim     160     189     19%     1,917     2,248
# ...

# %% [markdown]
# ### Two Tables in a Page
#
# ![10.png](attachment:10.png)

# %%
# extract all the tables in the PDF file

tables = camelot.read_pdf("C:/Users/LENOVO/Desktop/Projects/Data Extraction/data/Table data/twotables_1.pdf", pages = 'all', flavor = "lattice")   #address of file location

# %%
print(f'Number of Tables : {tables.n}')
# Out:
# Number of Tables : 2

# %%
df_first = tables[0].df
df_first
# Out:
#            0                   1                 2  \
# 0  Sl. \nNo.  Name of \nState/UT  Name of District
# 1                    West Bengal           Bankura
# 2
#
#                                     3                 4                5  \
# 0                    Disease/ Illness  No. \nof \nCases  No. of \nDeaths
# 1  xix.  Acute \nDiarrhoeal \nDisease                46                0
# 2   xx.  Acute \nDiarrhoeal \nDisease                34                0
#
#                                6                    7                 8  \
# 0  Date of \nstart of \noutbreak  Date of \nreporting  Current \nStatus
# 1                       10/11/13             15/11/13   Under \nControl
# 2                       10/11/13             14/11/13   Under \nControl
#
#                                                    9
# 0                             Comments/ Action taken
# 1  Cases  of \nloose  motion  and  vomiting \nrep...
# 2  Cases  of \nloose  motion  and  vomiting \nrep...

# %%
df_second = tables[1].df
df_second
# Out:
#                                                    0                   1  \
# 0  DISEASE OUTBREAKS  OF PREVIOUS WEEKS REPORTED ...
# 1                                           Sl. \nNo  Name of \nState/UT
# 2                                                  1               Bihar
# 3
# 4
#
#                   2                                    3      4       5  \
# 0
# 1  Name of District                     Disease/ Illness  Cases  Deaths
# 2         Madhubani    xxi. Acute \nDiarrhoeal \nDisease     69       0
# 3         Madhubani   xxii. Acute \nDiarrhoeal \nDisease     30       1
# 4           Katihar  xxiii. Acute \nDiarrhoeal \nDisease     13       3
#
#                                6                 7  \
# 0
# 1  Date of \nstart of \noutbreak  Current \nStatus
# 2                       30/09/13   Under \nControl
# 3                       28/10/13   Under \nControl
# 4                       24/10/13   Under \ncontrol
#
# ...
